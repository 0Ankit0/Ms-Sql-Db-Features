-- %% [markdown]
-- make sure to tick .net framework project and item template while installing or if you have already installed visual studio then modify it , tick the option and then continue.
--
-- ![](data:image/png;base64,...)
